# %% [markdown]
# # WorldWide happiness Analysis with Python and Power BI

# %% [markdown]
# ## Problem Identification and Overview

# %% [markdown]
# ## Methodology

# %% [markdown]
# ## Define Requirements

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Configuring pandas

# %%
## configure Pandas to display all columns

pd.set_option("display.max.columns", None)

# %%
## change columns to maximum of 2 decimal places

pd.set_option("display.precision", 2)

# %% [markdown]
# ## Importing the dataset

# %%
## reading data from the dataset in csv format.

happy = pd.read_csv('C:/Users/Lenovo/Desktop/A4-Main/WorldWide happiness report/worldwide_happiness_report.csv')

# %% [markdown]
# ## Understanding of DataSet

# %%
# check the length

len(happy)
# Out:
# 156

# %%
# check out the dimension of the dataset

happy.shape
# Out:
# (156, 9)

# %%
# look at the data types for each column

happy.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
# read the first five rows

happy.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland   7.77            1.34            1.59
# 1             2           Denmark   7.60            1.38            1.57
# 2             3            Norway   7.55            1.49            1.58
# 3             4           Iceland   7.49            1.38            1.62
# 4             5       Netherlands   7.49            1.40            1.52
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     0.99                          0.60        0.15
# 1                     1.00                          0.59        0.25
# 2                     1.03                          0.60        0.27
# 3                     1.03                          0.59        0.35
# 4                     1.00                          0.56        0.32
#
#    Perceptions of corruption
# 0                       0.39
# 1                       0.41
# 2                       0.34
# 3                       0.12
# 4                       0.30

# %%
# read the last five rows

happy.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda   3.33            0.36
# 152           153                  Tanzania   3.23            0.48
# 153           154               Afghanistan   3.20            0.35
# 154           155  Central African Republic   3.08            0.03
# 155           156               South Sudan   2.85            0.31
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151            0.71                     0.61                          0.56
# 152            0.89                     0.50                          0.42
# 153            0.52                     0.36                          0.00
# 154            0.00                     0.10                          0.23
# 155            0.57                     0.29                          0.01
#
#      Generosity  Perceptions of corruption
# 151        0.22                       0.41
# 152        0.28                       0.15
# 153        0.16                       0.03
# 154        0.23                       0.04
# 155        0.20                       0.09

# %%
# return an array of column names

happy.columns.values
# Out:
# array(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'], dtype=object)

# %%
# return a list of column names

happy.columns.values.tolist()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
# check data set information

happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# describe the data set

happy.describe()
# Out:
#        Overall rank   Score  GDP per capita  Social support  \
# count        156.00  156.00          156.00          156.00
# mean          78.50    5.41            0.91            1.21
# std           45.18    1.11            0.40            0.30
# min            1.00    2.85            0.00            0.00
# 25%           39.75    4.54            0.60            1.06
# 50%           78.50    5.38            0.96            1.27
# 75%          117.25    6.18            1.23            1.45
# max          156.00    7.77            1.68            1.62
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count                   156.00                        156.00      156.00
# mean                      0.73                          0.39        0.18
# std                       0.24                          0.14        0.10
# min                       0.00                          0.00        0.00
# 25%                       0.55                          0.31        0.11
# 50%                       0.79                          0.42        0.18
# 75%                       0.88                          0.51        0.25
# max                       1.14                          0.63        0.57
#
#        Perceptions of corruption
# count                     156.00
# mean                        0.11
# std                         0.09
# min                         0.00
# 25%                         0.05
# 50%                         0.09
# 75%                         0.14
# max                         0.45

# %%
## describe all data types, not limiting to numeric (floats) columns

happy.describe(include=object)
# Out:
#        Country or region
# count                156
# unique               156
# top                Malta
# freq                   1

# %% [markdown]
# ## Sanity Checks and Resolution

# %% [markdown]
# ### checking missing values

# %%
# checking missing values in whole data set

happy.isnull()
# Out:
#      Overall rank  Country or region  Score  GDP per capita  Social support  \
# 0           False              False  False           False           False
# 1           False              False  False           False           False
# 2           False              False  False           False           False
# 3           False              False  False           False           False
# 4           False              False  False           False           False
# ..            ...                ...    ...             ...             ...
# 151         False              False  False           False           False
# 152         False              False  False           False           False
# 153         False              False  False           False           False
# 154         False              False  False           False           False
# 155         False              False  False           False           False
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      False                         False       False
# 1                      False                         False       False
# 2                      False                         False       False
# 3                      False                         False       False
# 4                      False                         False       False
# ..                       ...                           ...         ...
# 151                    False                         False       False
# 152                    False                         False       False
# 153                    False                         False       False
# 154                    False                         False       False
# 155                    False                         False       False
#
#      Perceptions of corruption
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ..                         ...
# 151                      False
# 152                      False
# 153                      False
# 154                      False
# 155                      False
#
# [156 rows x 9 columns]

# %%
# checking non-missing values in Score column

happy["Score"].isnull().sum()
# Out:
# 0

# %%
# only want to know if there are any missing values

happy.isnull().any()
# Out:
# Overall rank                    False
# Country or region               False
# Score                           False
# GDP per capita                  False
# Social support                  False
# Healthy life expectancy         False
# Freedom to make life choices    False
# Generosity                      False
# Perceptions of corruption       False
# dtype: bool

# %%
happy.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# ## Checking for Duplicates

# %%
# remove duplicates, if any, and save the changes to the original data

happy.drop_duplicates(inplace=True)

# %%
happy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Exploratory data analysis can help you answer questions about your dataset. For example, you can examine how often specific values occur in a column

# %%
happy.corr()
# Out:
#                               Overall rank  Score  GDP per capita  \
# Overall rank                          1.00  -0.99           -0.80
# Score                                -0.99   1.00            0.79
# GDP per capita                       -0.80   0.79            1.00
# Social support                       -0.77   0.78            0.75
# Healthy life expectancy              -0.79   0.78            0.84
# Freedom to make life choices         -0.55   0.57            0.38
# Generosity                           -0.05   0.08           -0.08
# Perceptions of corruption            -0.35   0.39            0.30
#
#                               Social support  Healthy life expectancy  \
# Overall rank                           -0.77                    -0.79
# Score                                   0.78                     0.78
# GDP per capita                          0.75                     0.84
# Social support                          1.00                     0.72
# Healthy life expectancy                 0.72                     1.00
# Freedom to make life choices            0.45                     0.39
# Generosity                             -0.05                    -0.03
# Perceptions of corruption               0.18                     0.30
#
#                               Freedom to make life choices  Generosity  \
# Overall rank                                         -0.55       -0.05
# Score                                                 0.57        0.08
# GDP per capita                                        0.38       -0.08
# Social support                                        0.45       -0.05
# Healthy life expectancy                               0.39       -0.03
# Freedom to make life choices                          1.00        0.27
# Generosity                                            0.27        1.00
# Perceptions of corruption                             0.44        0.33
#
#                               Perceptions of corruption
# Overall rank                                      -0.35
# Score                                              0.39
# GDP per capita                                     0.30
# Social support                                     0.18
# Healthy life expectancy                            0.30
# Freedom to make life choices                       0.44
# Generosity                                         0.33
# Perceptions of corruption                          1.00

# %%
### exHappy = happy["Country or region"][0:31]
### fairlyHappy = happy["Country or region"][31:71]
### unHappy = happy["Country or region"][71:121]
### exSad = happy["Country or region"][121:156]

# %%
exHappy = happy["Country or region"][0:31]
fairlyHappy = happy["Country or region"][31:71]
unHappy = happy["Country or region"][71:121]
exSad = happy["Country or region"][121:156]

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.set(font_scale=1.5)
ax = sns.boxplot(x=happy['Overall rank'], y=happy["Generosity"], hue=happy["Country or region"])
ax.set_ylabel('Countires')

plt.title('Overall rank and Generosity', fontsize = 20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.set(font_scale=1.5)
ax = sns.scatterplot(y=exSad, x=happy['Generosity'], color='#6c7d27', s=70, edgecolor='black', linewidth=0.3)
ax.set_ylabel('Countries')

plt.title('Gereosity level in sad Countries', fontsize = 20, color='#6c7d27' )
plt.show()

# %%
happy.describe().loc[['std','max','std','mean']]
# Out:
#       Overall rank  Score  GDP per capita  Social support  \
# std          45.18   1.11            0.40            0.30
# max         156.00   7.77            1.68            1.62
# std          45.18   1.11            0.40            0.30
# mean         78.50   5.41            0.91            1.21
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
# std                      0.24                          0.14        0.10
# max                      1.14                          0.63        0.57
# std                      0.24                          0.14        0.10
# mean                     0.73                          0.39        0.18
#
#       Perceptions of corruption
# std                        0.09
# max                        0.45
# std                        0.09
# mean                       0.11

# %%
happy['Score'].describe().loc[['mean']]
# Out:
# mean    5.41
# Name: Score, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(5,8))
sns.set(font_scale=1.5)
ax = sns.boxplot(y=happy["Score"], color="#086964")
ax.axhline(y=happy['Score'].max(), linestyle='--',color='#6c7507', label=f'Max Score ({happy.Score.max()})')
ax.axhline(y=happy['Score'].describe()[6], linestyle='--',color='#086964', label=f'75% Score ({happy.Score.describe()[6]:.2f})')
ax.axhline(y=happy['Score'].median(), linestyle='--',color='#190587', label=f'Median Score ({happy.Score.median():.2f})')
ax.axhline(y=happy['Score'].describe()[4], linestyle='--',color='#190587', label=f'25% Score ({happy.Score.describe()[4]:.2f})')
ax.axhline(y=happy['Score'].min(), linestyle='--',color='#046ebf', label=f'Min Score ({happy.Score.min()})')
ax.legend(fontsize='xx-small', loc='upper right')
ax.set_ylabel('Country or region')

plt.title('Happiness Distribution', fontsize = 20)
plt.show()

# %%
happy[["Country or region", "Generosity" ]][21:31]
# Out:
#    Country or region  Generosity
# 21             Malta        0.38
# 22            Mexico        0.07
# 23            France        0.11
# 24            Taiwan        0.24
# 25             Chile        0.19
# 26         Guatemala        0.17
# 27      Saudi Arabia        0.08
# 28             Qatar        0.22
# 29             Spain        0.15
# 30            Panama        0.11

# %%
# set the colors
cmap = plt.get_cmap('Pastel1')
young = cmap(0.5)
middle = cmap(0.2)
older = cmap(0.8)

# %%
sns.set()
sns.set_style('whitegrid')

# %% [markdown]
#     _Line Plot
#     Scatter Plot
#     Box plot
#     Point plot
#     Count plot
#     Violin plot
#     Swarm plot
#     Bar plot
#     KDE Plot_

# %%
nationality = happy['Country or region']
topTen = nationality[:20]

# %%
#Scatter plot
plt.figure(figsize=(14, 10))  
plt.title('Score relative to Social support of most happy Countries', 
          fontsize = 20)
ax = sns.scatterplot(x = 'Score',
                     y = happy['Social support'],
                     hue = exHappy,
                     data = happy,
                     legend="full",
                     alpha = 0.4
                    )

# %%
sns.lineplot(x=nationality[:5],y="Freedom to make life choices", color='g',data=happy)
# Out:
# <AxesSubplot: xlabel='Country or region', ylabel='Freedom to make life choices'>

# %%
happy['Social support'].hist()
plt.title("Social support")
# Out:
# Text(0.5, 1.0, 'Social support')

# %%
happy["Country or region"].count()
# Out:
# 156

# %%
sns.distplot(happy.Score, color='g', bins=20, kde = True)
# Out:
# <AxesSubplot: xlabel='Score'>

# %%
sns.jointplot(x="Generosity",y="Score", color='g',data=happy, kind="kde")

# %%
sns.boxplot(happy.Score, orient='H', palette='summer')
# Out:
# <AxesSubplot: xlabel='Score'>

# %%
sns.catplot(x='Score', y='Perceptions of corruption', data=happy)

# %%
sns.heatmap(happy.corr(), cmap='BrBG', linewidths=0.5, linecolor='green')
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(happy.corr(), square=True, annot=True, linewidths=3)
# Out:
# <AxesSubplot: >

# %%
sns.violinplot(happy.Score, color='g')
# Out:
# <AxesSubplot: xlabel='Score'>

# %%
sns.countplot(happy["Social support"])
# Out:
# <AxesSubplot: xlabel='Social support', ylabel='count'>

# %%
sns.lineplot(happy["Social support"], happy["Score"])
# Out:
# <AxesSubplot: xlabel='Social support', ylabel='Score'>

# %%
figure(figsize=(14, 10)) 

ax = sns.scatterplot(happy["Social support"], happy["Score"], hue =happy["Country or region"])

# %%
sns.boxplot(happy["Social support"], happy["Score"])
# Out:
# <AxesSubplot: xlabel='Social support', ylabel='Score'>

# %%
sns.swarmplot(x = happy["Social support"], y = happy["Country or region"])
# Out:
# <AxesSubplot: xlabel='Social support', ylabel='Country or region'>

# %%
sns.kdeplot( happy['Generosity'], happy['Score'])
# Out:
# <AxesSubplot: xlabel='Generosity', ylabel='Score'>

# %%
sns.pairplot(happy[["Country or region", "Perceptions of corruption","Generosity", "Freedom to make life choices", "Healthy life expectancy", "Score", "GDP per capita", "Social support"]])

# %%
g = sns.pairplot(happy[["Country or region", "Perceptions of corruption","Generosity", "Freedom to make life choices", "Healthy life expectancy", "Score", "GDP per capita", "Social support"]])

# %%
g.map(sns.scatterplot)

# %%
g = sns.pairplot(happy[["Country or region", "Perceptions of corruption","Generosity", "Freedom to make life choices", "Healthy life expectancy", "Score", "GDP per capita", "Social support"]])
g.map_offdiag(sns.scatterplot)
g.map_diag(sns.histplot);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-193-12bbd13bebc2> in <module>
#       1 g = sns.pairplot(happy[["Country or region", "Perceptions of corruption","Generosity", "Freedom to make life choices", "Healthy life expectancy", "Score", "GDP per capita", "Social support"]])
#       2 g.map_offdiag(sns.scatterplot)
# ----> 3 g.map_diag(sns.histplot);
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
g = sns.pairplot(happy[["Country or region", "Perceptions of corruption","Generosity", "Freedom to make life choices", "Healthy life expectancy", "Score", "GDP per capita", "Social support"]])

g.map_lower(sns.scatterplot)
g.map_upper(sns.kdeplot)

g.map_diag(sns.histplot);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-194-d02adfba0664> in <module>
#       4 g.map_upper(sns.kdeplot)
#       5
# ----> 6 g.map_diag(sns.histplot);
#       7
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
g = sns.pairplot(happy[["Country or region", "Perceptions of corruption","Generosity", "Freedom to make life choices", "Healthy life expectancy", "Score", "GDP per capita", "Social support"]])

g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-195-7a5d315212dd> in <module>
#       1 g = sns.pairplot(happy[["Country or region", "Perceptions of corruption","Generosity", "Freedom to make life choices", "Healthy life expectancy", "Score", "GDP per capita", "Social support"]])
#       2
# ----> 3 g.map_diag(sns.histplot)
#       4 g.map_offdiag(sns.scatterplot)
#       5 g.add_legend();
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %% [markdown]
# ## Communicate Results

# %% [markdown]
# ## Interpreting the Results / Recommendations

# %% [markdown]
# ## Generating Reports/Story/Insights/

# %% [markdown]
# ## Conclusion
